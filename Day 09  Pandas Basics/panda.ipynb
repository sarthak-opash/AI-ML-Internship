# %% [markdown]
# Library Imported

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv",index_col='Customer Id')
print(data.head())
# Out:
#                  Index First Name Last Name                          Company  \
# Customer Id
# DD37Cf93aecA6Dc      1     Sheryl    Baxter                  Rasmussen Group
# 1Ef7b82A4CAAD10      2    Preston    Lozano                      Vega-Gentry
# 6F94879bDAfE5a6      3        Roy     Berry                    Murillo-Perry
# 5Cef8BFA16c5e3c      4      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 053d585Ab6b3159      5     Joanna    Bender         Martin, Lang and Andrade
#
#                               City                     Country  \
# Customer Id
# DD37Cf93aecA6Dc       East Leonard                       Chile
# 1Ef7b82A4CAAD10  East Jimmychester                    Djibouti
# 6F94879bDAfE5a6      Isabelborough         Antigua and Barbuda
# 5Cef8BFA16c5e3c         Bensonview          Dominican Republic
# 053d585Ab6b3159     West Priscilla  Slovakia (Slovak Republic)
#
#                                 Phone 1                Phone 2  \
# Customer Id
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, DD37Cf93aecA6Dc to 2354a0E336A91A1
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   First Name         100 non-null    object
#  2   Last Name          100 non-null    object
#  3   Company            100 non-null    object
#  4   City               100 non-null    object
#  5   Country            100 non-null    object
#  6   Phone 1            100 non-null    object
#  7   Phone 2            100 non-null    object
#  8   Email              100 non-null    object
#  9   Subscription Date  100 non-null    object
#  10  Website            100 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 9.4+ KB
# None

# %%
group = data.groupby('Company')['Website'].sum()
print(group.head())
# Out:
# Company
# Acosta, Petersen and Morrow    http://www.hawkins-ramsey.com/
# Adkins-Salinas                     https://patel-hanson.info/
# Anderson Ltd                               http://spence.com/
# Beck-Hendrix                               https://arias.com/
# Blankenship-Arias                     https://www.juarez.com/
# Name: Website, dtype: object

# %%
print(data.head(2))
# Out:
#                  Index First Name Last Name          Company  \
# Customer Id
# DD37Cf93aecA6Dc      1     Sheryl    Baxter  Rasmussen Group
# 1Ef7b82A4CAAD10      2    Preston    Lozano      Vega-Gentry
#
#                               City   Country       Phone 1           Phone 2  \
# Customer Id
# DD37Cf93aecA6Dc       East Leonard     Chile  229.077.5154  397.884.0519x718
# 1Ef7b82A4CAAD10  East Jimmychester  Djibouti    5153435776  686-620-1820x944
#
#                                     Email Subscription Date  \
# Customer Id
# DD37Cf93aecA6Dc  zunigavanessa@smith.info        2020-08-24
# 1Ef7b82A4CAAD10           vmata@colon.com        2021-04-23
#
#                                     Website
# Customer Id
# DD37Cf93aecA6Dc  http://www.stephenson.com/
# 1Ef7b82A4CAAD10       http://www.hobbs.com/

# %%
print(data.head(1))
# Out:
#                  Index First Name Last Name          Company          City  \
# Customer Id
# DD37Cf93aecA6Dc      1     Sheryl    Baxter  Rasmussen Group  East Leonard
#
#                 Country       Phone 1           Phone 2  \
# Customer Id
# DD37Cf93aecA6Dc   Chile  229.077.5154  397.884.0519x718
#
#                                     Email Subscription Date  \
# Customer Id
# DD37Cf93aecA6Dc  zunigavanessa@smith.info        2020-08-24
#
#                                     Website
# Customer Id
# DD37Cf93aecA6Dc  http://www.stephenson.com/

# %%
name_company = data[["First Name","Company"]]
print(name_company.head(10))
# Out:
#                 First Name                          Company
# Customer Id
# DD37Cf93aecA6Dc     Sheryl                  Rasmussen Group
# 1Ef7b82A4CAAD10    Preston                      Vega-Gentry
# 6F94879bDAfE5a6        Roy                    Murillo-Perry
# 5Cef8BFA16c5e3c      Linda  Dominguez, Mcmillan and Donovan
# 053d585Ab6b3159     Joanna         Martin, Lang and Andrade
# 2d08FB17EE273F4      Aimee                     Steele Group
# EA4d384DfDbBf77     Darren     Lester, Woodard and Mitchell
# 0e04AFde9f225dE      Brett     Sanford, Davenport and Giles
# C2dE4dEEc489ae0     Sheryl                   Browning-Simon
# 8C2811a503C7c5a   Michelle                     Beck-Hendrix

# %%
row = data.loc["0e04AFde9f225dE"]
print(row)
# Out:
# Index                                           8
# First Name                                  Brett
# Last Name                                  Mullen
# Company              Sanford, Davenport and Giles
# City                                      Kimport
# Country                                  Bulgaria
# Phone 1                      001-583-352-7197x297
# Phone 2                          001-333-145-0369
# Email                             asnow@colon.com
# Subscription Date                      2021-04-12
# Website               https://hammond-ramsey.com/
# Name: 0e04AFde9f225dE, dtype: object

# %%
print(data.tail())
# Out:
#                  Index First Name Last Name                Company  \
# Customer Id
# cb8E23e48d22Eae     96       Karl     Greer              Carey LLC
# CeD220bdAaCfaDf     97       Lynn  Atkinson  Ware, Burns and Oneal
# 28CDbC0dFe4b1Db     98       Fred    Guerra          Schmitt-Jones
# c23d1D9EE8DEB0A     99     Yvonne    Farmer     Fitzgerald-Harrell
# 2354a0E336A91A1    100   Clarence    Haynes     Le, Nash and Cross
#
#                             City          Country               Phone 1  \
# Customer Id
# cb8E23e48d22Eae     East Richard           Guyana   (188)169-1674x58692
# CeD220bdAaCfaDf     New Bradview        Sri Lanka       +1-846-706-2218
# 28CDbC0dFe4b1Db       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# c23d1D9EE8DEB0A  Lake Elijahview            Aruba         (530)311-9786
# 2354a0E336A91A1        Judymouth         Honduras         (753)813-6941
#
#                                 Phone 2                           Email  \
# Customer Id
# ...

# %%
value = data.at["cb8E23e48d22Eae", "City"]
print(value)
# Out:
# East Richard

# %%
from pandas import read_csv


data1 = read_csv("data.csv", skiprows = [4,5,6,8,11])
print(data1)
# Out:
#     Index      Customer Id First Name Last Name                       Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter               Rasmussen Group
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano                   Vega-Gentry
# 2       3  6F94879bDAfE5a6        Roy     Berry                 Murillo-Perry
# 3       7  EA4d384DfDbBf77     Darren      Peck  Lester, Woodard and Mitchell
# 4       9  C2dE4dEEc489ae0     Sheryl    Meyers                Browning-Simon
# ..    ...              ...        ...       ...                           ...
# 90     96  cb8E23e48d22Eae       Karl     Greer                     Carey LLC
# 91     97  CeD220bdAaCfaDf       Lynn  Atkinson         Ware, Burns and Oneal
# 92     98  28CDbC0dFe4b1Db       Fred    Guerra                 Schmitt-Jones
# 93     99  c23d1D9EE8DEB0A     Yvonne    Farmer            Fitzgerald-Harrell
# 94    100  2354a0E336A91A1   Clarence    Haynes            Le, Nash and Cross
#
# ...

# %%
data.sort_values(by ="Customer Id", ascending=True).head(10)
# Out:
#                  Index First Name   Last Name                       Company  \
# Customer Id
# 010468dAA11382c     24      Janet  Valenzuela               Watts-Donaldson
# 03A1E62ADdeb31c     85      Corey        Holt    Mcdonald, Bird and Ramirez
# 053d585Ab6b3159      5     Joanna      Bender      Martin, Lang and Andrade
# 09D7D7C8Fe09aea     26     Marcus       Moody                     Giles Ltd
# 0F60FF3DdCd7aB0     20     Joanna        Kirk                Mays-Mccormick
# 0e04AFde9f225dE      8      Brett      Mullen  Sanford, Davenport and Giles
# 17aD8e2dB3df03D     40     Sherry       Garza                  Anderson Ltd
# 1Ef7b82A4CAAD10      2    Preston      Lozano                   Vega-Gentry
# 216E205d6eBb815     11       Carl   Schroeder    Oconnell, Meza and Everett
# 2354a0E336A91A1    100   Clarence      Haynes            Le, Nash and Cross
#
#                               City                           Country  \
# Customer Id
# ...
