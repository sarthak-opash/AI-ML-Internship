# %%
! pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 10.2 MB/s  0:00:00
# ...
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.plotting import plot_decision_regions

# %%
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target

data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
X, y = iris.data[:, 2:], iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123, shuffle=True)

# %%
plt.scatter(X_train[y_train == 0, 0], X_train[y_train == 0, 1], marker='o', label='Setosa')
plt.scatter(X_train[y_train == 1, 0], X_train[y_train == 1, 1], marker='^', label='Versicolor')
plt.scatter(X_train[y_train == 2, 0], X_train[y_train == 2, 1], marker='s', label='Virginica')

plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend()
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn_fit = knn.fit(X_train, y_train)
knn_fit
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_fit.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)*100
# Out:
# 95.55555555555556

# %%
plot_decision_regions(X_train, y_train, knn_fit)
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.show()

# %%
plot_decision_regions(X_test, y_test, knn_fit)
plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend()
plt.show()
