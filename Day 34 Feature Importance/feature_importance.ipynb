# %%
import pandas as pd 
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor
import numpy as np 
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("Diamond Price Prediction.csv")
data
# Out:
#        Carat(Weight of Daimond) Cut(Quality) Color Clarity  Depth  Table  \
# 0                          0.23        Ideal     E     SI2   61.5   55.0
# 1                          0.21      Premium     E     SI1   59.8   61.0
# 2                          0.23         Good     E     VS1   56.9   65.0
# 3                          0.29      Premium     I     VS2   62.4   58.0
# 4                          0.31         Good     J     SI2   63.3   58.0
# ...                         ...          ...   ...     ...    ...    ...
# 53935                      0.72        Ideal     D     SI1   60.8   57.0
# 53936                      0.72         Good     D     SI1   63.1   55.0
# 53937                      0.70    Very Good     D     SI1   62.8   60.0
# 53938                      0.86      Premium     H     SI2   61.0   58.0
# 53939                      0.75        Ideal     D     SI2   62.2   55.0
#
#        Price(in US dollars)  X(length)  Y(width)  Z(Depth)
# ...

# %%
data.isnull().sum()
# Out:
# Carat(Weight of Daimond)    0
# Cut(Quality)                0
# Color                       0
# Clarity                     0
# Depth                       0
# Table                       0
# Price(in US dollars)        0
# X(length)                   0
# Y(width)                    0
# Z(Depth)                    0
# dtype: int64

# %%
data.dtypes
# Out:
# Carat(Weight of Daimond)    float64
# Cut(Quality)                 object
# Color                        object
# Clarity                      object
# Depth                       float64
# Table                       float64
# Price(in US dollars)          int64
# X(length)                   float64
# Y(width)                    float64
# Z(Depth)                    float64
# dtype: object

# %%
cols = ['Cut(Quality)', 'Color', "Clarity"]
    
for col in cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#        Carat(Weight of Daimond)  Cut(Quality)  Color  Clarity  Depth  Table  \
# 0                          0.23             2      1        3   61.5   55.0
# 1                          0.21             3      1        2   59.8   61.0
# 2                          0.23             1      1        4   56.9   65.0
# 3                          0.29             3      5        5   62.4   58.0
# 4                          0.31             1      6        3   63.3   58.0
# ...                         ...           ...    ...      ...    ...    ...
# 53935                      0.72             2      0        2   60.8   57.0
# 53936                      0.72             1      0        2   63.1   55.0
# 53937                      0.70             4      0        2   62.8   60.0
# 53938                      0.86             3      4        3   61.0   58.0
# 53939                      0.75             2      0        3   62.2   55.0
#
# ...

# %%
data.corr()
# Out:
#                           Carat(Weight of Daimond)  Cut(Quality)     Color  \
# Carat(Weight of Daimond)                  1.000000      0.017124  0.291437
# Cut(Quality)                              0.017124      1.000000  0.000304
# Color                                     0.291437      0.000304  1.000000
# Clarity                                  -0.214290      0.028235 -0.027795
# Depth                                     0.028224     -0.194249  0.047279
# Table                                     0.181618      0.150327  0.026465
# Price(in US dollars)                      0.921591      0.039860  0.172511
# X(length)                                 0.975094      0.022342  0.270287
# Y(width)                                  0.951722      0.027572  0.263584
# Z(Depth)                                  0.953387      0.002037  0.268227
#
#                            Clarity     Depth     Table  Price(in US dollars)  \
# ...

# %%
X = data.drop("Price(in US dollars)", axis=1)
y = data['Price(in US dollars)']

# %%
from sklearn.model_selection._split import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)*100
# Out:
# 98.11511106067464

# %%
model.feature_importances_.tolist()
# Out:
# [0.6276363178823038,
#  0.0013967170078879533,
#  0.02839936383114011,
#  0.06533604929204395,
#  0.0032169046049498797,
#  0.002430190331729254,
#  0.005817233370186736,
#  0.26039820212935627,
#  0.005369021550402211]

# %%
feature_importance_data = pd.DataFrame(
    {
        'Feature Name': X.columns,
        "Importance": model.feature_importances_
    }
)

# %%
sorted_data = feature_importance_data.sort_values(by="Importance", ascending=False)

# %%
import matplotlib.pyplot as plt

plt.barh(
    feature_importance_data["Feature Name"],
    feature_importance_data["Importance"]
)
plt.title("Feature Importance")
plt.gca().invert_yaxis()
plt.xlabel("Importance")
plt.ylabel("Feature Name")
plt.tight_layout()
plt.show()

# %%
sorted_data.head(5)
# Out:
#                Feature Name  Importance
# 0  Carat(Weight of Daimond)    0.627636
# 7                  Y(width)    0.260398
# 3                   Clarity    0.065336
# 2                     Color    0.028399
# 6                 X(length)    0.005817

# %%
X_featured = data.drop(columns=['Cut(Quality)', 'Depth', 'Table', 'Z(Depth)'])

# %%
X_featured_train, X_featured_test, y_train, y_test = train_test_split(X_featured, y, test_size=0.3, random_state=42)

# %%
model_featured = RandomForestRegressor()
model_featured.fit(X_featured_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_featured = model_featured.predict(X_featured_test)

# %%
r2_score(y_test, y_pred_featured)*100
# Out:
# 99.99999665592325
