# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing 
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from statistics import mean

# %%
cancer = datasets.load_breast_cancer()

X = cancer.data
y = cancer.target

# %%
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
stratified = []

# %%
linreg_score = cross_val_score(LinearRegression(), X, y, cv=skf)
linreg_score


for i, result in enumerate(linreg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {linreg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 66.21%
# Fold 2: 73.32%
# Fold 3: 72.93%
# Fold 4: 73.91%
# Fold 5: 71.46%
# Fold 6: 76.82%
# Fold 7: 74.04%
# Fold 8: 71.52%
# Fold 9: 78.63%
# Fold 10: 79.06%
# Mean Accuracy: 73.79%

# %% [markdown]
# # RandomForest

# %%
rf_reg_score = cross_val_score(RandomForestClassifier(), X, y, cv=skf)
rf_reg_score


for i, result in enumerate(rf_reg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {rf_reg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 94.74%
# Fold 2: 94.74%
# Fold 3: 98.25%
# Fold 4: 100.00%
# Fold 5: 94.74%
# Fold 6: 94.74%
# Fold 7: 100.00%
# Fold 8: 94.74%
# Fold 9: 96.49%
# Fold 10: 92.86%
# Mean Accuracy: 96.13%

# %%
f_reg_score = cross_val_score(RandomForestClassifier(max_depth=10), X, y, cv=skf)
rf_reg_score


for i, result in enumerate(rf_reg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {rf_reg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 94.74%
# Fold 2: 94.74%
# Fold 3: 98.25%
# Fold 4: 100.00%
# Fold 5: 94.74%
# Fold 6: 94.74%
# Fold 7: 100.00%
# Fold 8: 94.74%
# Fold 9: 96.49%
# Fold 10: 92.86%
# Mean Accuracy: 96.13%

# %%
f_reg_score = cross_val_score(RandomForestClassifier(max_depth=5), X, y, cv=skf)
rf_reg_score


for i, result in enumerate(rf_reg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {rf_reg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 94.74%
# Fold 2: 94.74%
# Fold 3: 98.25%
# Fold 4: 100.00%
# Fold 5: 94.74%
# Fold 6: 94.74%
# Fold 7: 100.00%
# Fold 8: 94.74%
# Fold 9: 96.49%
# Fold 10: 92.86%
# Mean Accuracy: 96.13%

# %%
dt_reg_score = cross_val_score(DecisionTreeClassifier(), X, y, cv=skf)
dt_reg_score

for i, result in enumerate(dt_reg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {dt_reg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 92.98%
# Fold 2: 91.23%
# Fold 3: 91.23%
# Fold 4: 91.23%
# Fold 5: 91.23%
# Fold 6: 94.74%
# Fold 7: 98.25%
# Fold 8: 91.23%
# Fold 9: 87.72%
# Fold 10: 96.43%
# Mean Accuracy: 92.63%

# %%
from xgboost import XGBClassifier
xg_score = cross_val_score(XGBClassifier(), X,y,cv=skf)

for i, result in enumerate(xg_score, 1):
    print(f"Fold {i}: {result * 100:.2f}%")
    
print(f'Mean Accuracy: {xg_score.mean()* 100:.2f}%')
# Out:
# Fold 1: 96.49%
# Fold 2: 98.25%
# Fold 3: 98.25%
# Fold 4: 98.25%
# Fold 5: 96.49%
# Fold 6: 94.74%
# Fold 7: 100.00%
# Fold 8: 94.74%
# Fold 9: 94.74%
# Fold 10: 98.21%
# Mean Accuracy: 97.01%
