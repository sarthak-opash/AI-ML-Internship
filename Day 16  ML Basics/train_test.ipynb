# %%
import pandas as pd
import numpy as no 
import matplotlib.pyplot as plt 
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(
    df['Mileage'],
    df['Sell Price($)']
)

# %%
plt.scatter(
    df['Age(yrs)'],
    df['Sell Price($)']
)

# %%
X = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 18    87600         8
# 15    25400         3
# 12    59000         5
# 10    83000         7
# 7     72000         6
# 9     67000         6
# 2     57000         5
# 13    58780         4
# 14    82450         7
# 17    69000         5
# 5     59000         5
# 0     69000         6
# 16    28000         2
# 8     91000         8

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 4     46000         4
# 19    52000         5
# 11    79000         7
# 3     22500         2
# 1     35000         3
# 6     52000         5

# %%
y_test
# Out:
# 4     31500
# 19    28200
# 11    19500
# 3     40000
# 1     34000
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
y_train
# Out:
# 18    12800
# 15    35000
# 12    26000
# 10    18700
# 7     19300
# 9     22000
# 2     26100
# 13    27500
# 14    19400
# 17    19700
# 5     26750
# 0     18000
# 16    35500
# 8     12000
# Name: Sell Price($), dtype: int64

# %%
le = LinearRegression()

# %%
le.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
le.predict(X_test)
# Out:
# array([29201.29941296, 26411.16453319, 17415.35263668, 37400.15147752,
#        33129.94833839, 26411.16453319])

# %%
scoree = le.score(X_test,y_test)
scoree
# Out:
# 0.7769309696368274
