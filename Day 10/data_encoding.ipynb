# %%
import sklearn.preprocessing as prep
import pandas as pd

# %%
data = ['red', 'blue', 'green', 'blue', 'red', 'green']
print(data)
# Out:
# ['red', 'blue', 'green', 'blue', 'red', 'green']

# %%
le = prep.LabelEncoder()
encoded = le.fit_transform(data)
print(encoded)
# Out:
# [2 0 1 0 2 1]

# %%
from sklearn.preprocessing import OrdinalEncoder
data = [['Low'], ['Medium'], ['High'], ['Medium'], ['Low']]

encoder = OrdinalEncoder(categories=[['Low', 'Medium', 'High']])
encoded_data = encoder.fit_transform(data)

print(f"Encoded Ordinal Data: {encoded_data}")
# Out:
# Encoded Ordinal Data: [[0.]
#  [1.]
#  [2.]
#  [1.]
#  [0.]]

# %%
data_diabetes = pd.read_csv('Diabetes Missing Data.csv')
encoding = le.fit_transform(data_diabetes['Class'])
print(encoding[:5])
# Out:
# [1 0 1 0 1]
