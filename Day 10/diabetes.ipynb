# %%
import pandas as pd

# %%
data = pd.read_csv("Diabetes Missing Data.csv")

# %%
print(data.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
print(data.isnull().sum())
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
print(data.fillna("NS"))
# Out:
#      Pregnant Glucose Diastolic_BP Skin_Fold Serum_Insulin   BMI  \
# 0           6   148.0         72.0      35.0            NS  33.6
# 1           1    85.0         66.0      29.0            NS  26.6
# 2           8   183.0         64.0        NS            NS  23.3
# 3           1    89.0         66.0      23.0          94.0  28.1
# 4           0   137.0         40.0      35.0         168.0  43.1
# ..        ...     ...          ...       ...           ...   ...
# 763        10   101.0         76.0      48.0         180.0  32.9
# 764         2   122.0         70.0      27.0            NS  36.8
# 765         5   121.0         72.0      23.0         112.0  26.2
# 766         1   126.0         60.0        NS            NS  30.1
# 767         1    93.0         70.0      31.0            NS  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# 2                0.672   32      1
# 3                0.167   21      0
# ...

# %%
print(data.isna().sum())
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
data.sort_values(by=['Age'],ascending=True).head(20)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 736         0    126.0          86.0       27.0          120.0  27.4
# 738         2     99.0          60.0       17.0          160.0  36.6
# 721         1    114.0          66.0       36.0          200.0  38.1
# 60          2     84.0           NaN        NaN            NaN   NaN
# 290         0     78.0          88.0       29.0           40.0  36.9
# 367         0    101.0          64.0       17.0            NaN  21.0
# 354         3     90.0          78.0        NaN            NaN  42.7
# 55          1     73.0          50.0       10.0            NaN  23.0
# 671         1     99.0          58.0       10.0            NaN  25.4
# 626         0    125.0          68.0        NaN            NaN  24.7
# 382         1    109.0          60.0        8.0          182.0  25.4
# 273         1     71.0          78.0       50.0           45.0  33.2
# 271         2    108.0          62.0       32.0           56.0  25.2
# ...
