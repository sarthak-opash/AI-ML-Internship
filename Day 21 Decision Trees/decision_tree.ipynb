# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score,classification_report

# %%
data = pd.read_csv("booking.csv")
data
# Out:
#       Booking_ID  number of adults  number of children  \
# 0       INN00001                 1                   1
# 1       INN00002                 1                   0
# 2       INN00003                 2                   1
# 3       INN00004                 1                   0
# 4       INN00005                 1                   0
# ...          ...               ...                 ...
# 36280   INN36282                 2                   0
# 36281   INN36283                 2                   0
# 36282   INN36284                 2                   0
# 36283   INN36285                 3                   0
# 36284   INN36286                 2                   0
#
#        number of weekend nights  number of week nights  type of meal  \
# 0                             2                      5   Meal Plan 1
# 1                             1                      3  Not Selected
# 2                             1                      3   Meal Plan 1
# 3                             0                      2   Meal Plan 1
# 4                             1                      2  Not Selected
# ...                         ...                    ...           ...
# 36280                         0                      2   Meal Plan 2
# 36281                         1                      3   Meal Plan 1
# 36282                         1                      3   Meal Plan 1
# 36283                         0                      4   Meal Plan 1
# 36284                         0                      5   Meal Plan 1
#
#        car parking space    room type  lead time market segment type  \
# 0                      0  Room_Type 1        224             Offline
# 1                      0  Room_Type 1          5              Online
# 2                      0  Room_Type 1          1              Online
# 3                      0  Room_Type 1        211              Online
# 4                      0  Room_Type 1         48              Online
# ...                  ...          ...        ...                 ...
# 36280                  0  Room_Type 1        346              Online
# 36281                  0  Room_Type 1         34              Online
# 36282                  0  Room_Type 4         83              Online
# 36283                  0  Room_Type 1        121             Offline
# 36284                  0  Room_Type 4         44              Online
#
#        repeated  P-C  P-not-C  average price  special requests  \
# 0             0    0        0          88.00                 0
# 1             0    0        0         106.68                 1
# 2             0    0        0          50.00                 0
# 3             0    0        0         100.00                 1
# 4             0    0        0          77.00                 0
# ...         ...  ...      ...            ...               ...
# 36280         0    0        0         115.00                 1
# 36281         0    0        0         107.55                 1
# 36282         0    0        0         105.61                 1
# 36283         0    0        0          96.90                 1
# 36284         0    0        0         133.44                 3
#
#       date of reservation booking status
# 0               10/2/2015   Not_Canceled
# 1               11/6/2018   Not_Canceled
# 2               2/28/2018       Canceled
# 3               5/20/2017       Canceled
# 4               4/11/2018       Canceled
# ...                   ...            ...
# 36280           9/13/2018       Canceled
# 36281          10/15/2017   Not_Canceled
# 36282          12/26/2018   Not_Canceled
# 36283            7/6/2018   Not_Canceled
# 36284          10/18/2018   Not_Canceled
#
# [36285 rows x 17 columns]

# %%
data.head()
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price  \
# 0        224             Offline         0    0        0          88.00
# 1          5              Online         0    0        0         106.68
# 2          1              Online         0    0        0          50.00
# 3        211              Online         0    0        0         100.00
# 4         48              Online         0    0        0          77.00
#
#    special requests date of reservation booking status
# 0                 0           10/2/2015   Not_Canceled
# 1                 1           11/6/2018   Not_Canceled
# 2                 0           2/28/2018       Canceled
# 3                 1           5/20/2017       Canceled
# 4                 0           4/11/2018       Canceled

# %%
data['room type'].value_counts()
# Out:
# room type
# Room_Type 1    28138
# Room_Type 4     6059
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64

# %%
data['type of meal'].value_counts()
# Out:
# type of meal
# Meal Plan 1     27842
# Not Selected     5132
# Meal Plan 2      3306
# Meal Plan 3         5
# Name: count, dtype: int64

# %%
data = data.drop(columns = ['Booking_ID', 'date of reservation'])

# %%
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# 0                          5   Meal Plan 1                  0  Room_Type 1
# 1                          3  Not Selected                  0  Room_Type 1
# 2                          3   Meal Plan 1                  0  Room_Type 1
# 3                          2   Meal Plan 1                  0  Room_Type 1
# 4                          2  Not Selected                  0  Room_Type 1
# ...                      ...           ...                ...          ...
# 36280                      2   Meal Plan 2                  0  Room_Type 1
# 36281                      3   Meal Plan 1                  0  Room_Type 1
# 36282                      3   Meal Plan 1                  0  Room_Type 4
# 36283                      4   Meal Plan 1                  0  Room_Type 1
# 36284                      5   Meal Plan 1                  0  Room_Type 4
#
#        lead time market segment type  repeated  P-C  P-not-C  average price  \
# 0            224             Offline         0    0        0          88.00
# 1              5              Online         0    0        0         106.68
# 2              1              Online         0    0        0          50.00
# 3            211              Online         0    0        0         100.00
# 4             48              Online         0    0        0          77.00
# ...          ...                 ...       ...  ...      ...            ...
# 36280        346              Online         0    0        0         115.00
# 36281         34              Online         0    0        0         107.55
# 36282         83              Online         0    0        0         105.61
# 36283        121             Offline         0    0        0          96.90
# 36284         44              Online         0    0        0         133.44
#
#        special requests booking status
# 0                     0   Not_Canceled
# 1                     1   Not_Canceled
# 2                     0       Canceled
# 3                     1       Canceled
# 4                     0       Canceled
# ...                 ...            ...
# 36280                 1       Canceled
# 36281                 1   Not_Canceled
# 36282                 1   Not_Canceled
# 36283                 1   Not_Canceled
# 36284                 3   Not_Canceled
#
# [36285 rows x 15 columns]

# %%
le = LabelEncoder()

# %%
data['meal'] = le.fit_transform(data['type of meal'])
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# 0                          5   Meal Plan 1                  0  Room_Type 1
# 1                          3  Not Selected                  0  Room_Type 1
# 2                          3   Meal Plan 1                  0  Room_Type 1
# 3                          2   Meal Plan 1                  0  Room_Type 1
# 4                          2  Not Selected                  0  Room_Type 1
# ...                      ...           ...                ...          ...
# 36280                      2   Meal Plan 2                  0  Room_Type 1
# 36281                      3   Meal Plan 1                  0  Room_Type 1
# 36282                      3   Meal Plan 1                  0  Room_Type 4
# 36283                      4   Meal Plan 1                  0  Room_Type 1
# 36284                      5   Meal Plan 1                  0  Room_Type 4
#
#        lead time market segment type  repeated  P-C  P-not-C  average price  \
# 0            224             Offline         0    0        0          88.00
# 1              5              Online         0    0        0         106.68
# 2              1              Online         0    0        0          50.00
# 3            211              Online         0    0        0         100.00
# 4             48              Online         0    0        0          77.00
# ...          ...                 ...       ...  ...      ...            ...
# 36280        346              Online         0    0        0         115.00
# 36281         34              Online         0    0        0         107.55
# 36282         83              Online         0    0        0         105.61
# 36283        121             Offline         0    0        0          96.90
# 36284         44              Online         0    0        0         133.44
#
#        special requests booking status  meal
# 0                     0   Not_Canceled     0
# 1                     1   Not_Canceled     3
# 2                     0       Canceled     0
# 3                     1       Canceled     0
# 4                     0       Canceled     3
# ...                 ...            ...   ...
# 36280                 1       Canceled     1
# 36281                 1   Not_Canceled     0
# 36282                 1   Not_Canceled     0
# 36283                 1   Not_Canceled     0
# 36284                 3   Not_Canceled     0
#
# [36285 rows x 16 columns]

# %%
data['room'] = le.fit_transform(data['room type'])
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  type of meal  car parking space    room type  \
# 0                          5   Meal Plan 1                  0  Room_Type 1
# 1                          3  Not Selected                  0  Room_Type 1
# 2                          3   Meal Plan 1                  0  Room_Type 1
# 3                          2   Meal Plan 1                  0  Room_Type 1
# 4                          2  Not Selected                  0  Room_Type 1
# ...                      ...           ...                ...          ...
# 36280                      2   Meal Plan 2                  0  Room_Type 1
# 36281                      3   Meal Plan 1                  0  Room_Type 1
# 36282                      3   Meal Plan 1                  0  Room_Type 4
# 36283                      4   Meal Plan 1                  0  Room_Type 1
# 36284                      5   Meal Plan 1                  0  Room_Type 4
#
#        lead time market segment type  repeated  P-C  P-not-C  average price  \
# 0            224             Offline         0    0        0          88.00
# 1              5              Online         0    0        0         106.68
# 2              1              Online         0    0        0          50.00
# 3            211              Online         0    0        0         100.00
# 4             48              Online         0    0        0          77.00
# ...          ...                 ...       ...  ...      ...            ...
# 36280        346              Online         0    0        0         115.00
# 36281         34              Online         0    0        0         107.55
# 36282         83              Online         0    0        0         105.61
# 36283        121             Offline         0    0        0          96.90
# 36284         44              Online         0    0        0         133.44
#
#        special requests booking status  meal  room
# 0                     0   Not_Canceled     0     0
# 1                     1   Not_Canceled     3     0
# 2                     0       Canceled     0     0
# 3                     1       Canceled     0     0
# 4                     0       Canceled     3     0
# ...                 ...            ...   ...   ...
# 36280                 1       Canceled     1     0
# 36281                 1   Not_Canceled     0     0
# 36282                 1   Not_Canceled     0     3
# 36283                 1   Not_Canceled     0     0
# 36284                 3   Not_Canceled     0     3
#
# [36285 rows x 17 columns]

# %%
data = data.drop(columns=['type of meal', 'room type'])

# %%
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  car parking space  lead time  \
# 0                          5                  0        224
# 1                          3                  0          5
# 2                          3                  0          1
# 3                          2                  0        211
# 4                          2                  0         48
# ...                      ...                ...        ...
# 36280                      2                  0        346
# 36281                      3                  0         34
# 36282                      3                  0         83
# 36283                      4                  0        121
# 36284                      5                  0         44
#
#       market segment type  repeated  P-C  P-not-C  average price  \
# 0                 Offline         0    0        0          88.00
# 1                  Online         0    0        0         106.68
# 2                  Online         0    0        0          50.00
# 3                  Online         0    0        0         100.00
# 4                  Online         0    0        0          77.00
# ...                   ...       ...  ...      ...            ...
# 36280              Online         0    0        0         115.00
# 36281              Online         0    0        0         107.55
# 36282              Online         0    0        0         105.61
# 36283             Offline         0    0        0          96.90
# 36284              Online         0    0        0         133.44
#
#        special requests booking status  meal  room
# 0                     0   Not_Canceled     0     0
# 1                     1   Not_Canceled     3     0
# 2                     0       Canceled     0     0
# 3                     1       Canceled     0     0
# 4                     0       Canceled     3     0
# ...                 ...            ...   ...   ...
# 36280                 1       Canceled     1     0
# 36281                 1   Not_Canceled     0     0
# 36282                 1   Not_Canceled     0     3
# 36283                 1   Not_Canceled     0     0
# 36284                 3   Not_Canceled     0     3
#
# [36285 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# number of adults            0
# number of children          0
# number of weekend nights    0
# number of week nights       0
# car parking space           0
# lead time                   0
# market segment type         0
# repeated                    0
# P-C                         0
# P-not-C                     0
# average price               0
# special requests            0
# booking status              0
# meal                        0
# room                        0
# dtype: int64

# %%
data['market segment type'].value_counts()
# Out:
# market segment type
# Online           23221
# Offline          10531
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: count, dtype: int64

# %%
sns.countplot(
    data = data,
    x = 'market segment type',
    hue = 'booking status'
)
# Out:
# <Axes: xlabel='market segment type', ylabel='count'>

# %%
data["booking status"] = data["booking status"].replace("Canceled", 1)
data["booking status"] = data["booking status"].replace("Not_Canceled", 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7804\1260294313.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["booking status"] = data["booking status"].replace("Not_Canceled", 0)

# %%
data['booking type'] = le.fit_transform(data['market segment type'])
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  car parking space  lead time  \
# 0                          5                  0        224
# 1                          3                  0          5
# 2                          3                  0          1
# 3                          2                  0        211
# 4                          2                  0         48
# ...                      ...                ...        ...
# 36280                      2                  0        346
# 36281                      3                  0         34
# 36282                      3                  0         83
# 36283                      4                  0        121
# 36284                      5                  0         44
#
#       market segment type  repeated  P-C  P-not-C  average price  \
# 0                 Offline         0    0        0          88.00
# 1                  Online         0    0        0         106.68
# 2                  Online         0    0        0          50.00
# 3                  Online         0    0        0         100.00
# 4                  Online         0    0        0          77.00
# ...                   ...       ...  ...      ...            ...
# 36280              Online         0    0        0         115.00
# 36281              Online         0    0        0         107.55
# 36282              Online         0    0        0         105.61
# 36283             Offline         0    0        0          96.90
# 36284              Online         0    0        0         133.44
#
#        special requests  booking status  meal  room  booking type
# 0                     0               0     0     0             3
# 1                     1               0     3     0             4
# 2                     0               1     0     0             4
# 3                     1               1     0     0             4
# 4                     0               1     3     0             4
# ...                 ...             ...   ...   ...           ...
# 36280                 1               1     1     0             4
# 36281                 1               0     0     0             4
# 36282                 1               0     0     3             4
# 36283                 1               0     0     0             3
# 36284                 3               0     0     3             4
#
# [36285 rows x 16 columns]

# %%
data = data.drop(columns='market segment type')
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 0                     1                   1                         2
# 1                     1                   0                         1
# 2                     2                   1                         1
# 3                     1                   0                         0
# 4                     1                   0                         1
# ...                 ...                 ...                       ...
# 36280                 2                   0                         0
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36283                 3                   0                         0
# 36284                 2                   0                         0
#
#        number of week nights  car parking space  lead time  repeated  P-C  \
# 0                          5                  0        224         0    0
# 1                          3                  0          5         0    0
# 2                          3                  0          1         0    0
# 3                          2                  0        211         0    0
# 4                          2                  0         48         0    0
# ...                      ...                ...        ...       ...  ...
# 36280                      2                  0        346         0    0
# 36281                      3                  0         34         0    0
# 36282                      3                  0         83         0    0
# 36283                      4                  0        121         0    0
# 36284                      5                  0         44         0    0
#
#        P-not-C  average price  special requests  booking status  meal  room  \
# 0            0          88.00                 0               0     0     0
# 1            0         106.68                 1               0     3     0
# 2            0          50.00                 0               1     0     0
# 3            0         100.00                 1               1     0     0
# 4            0          77.00                 0               1     3     0
# ...        ...            ...               ...             ...   ...   ...
# 36280        0         115.00                 1               1     1     0
# 36281        0         107.55                 1               0     0     0
# 36282        0         105.61                 1               0     0     3
# 36283        0          96.90                 1               0     0     0
# 36284        0         133.44                 3               0     0     3
#
#        booking type
# 0                 3
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 36280             4
# 36281             4
# 36282             4
# 36283             3
# 36284             4
#
# [36285 rows x 15 columns]

# %%
sns.histplot(data["number of adults"],bins=range(0,6))
# Out:
# <Axes: xlabel='number of adults', ylabel='Count'>

# %%
sns.histplot(data["number of children"],bins=range(0,6))
# Out:
# <Axes: xlabel='number of children', ylabel='Count'>

# %%
sns.histplot(data["number of weekend nights"],bins=range(0,6))
# Out:
# <Axes: xlabel='number of weekend nights', ylabel='Count'>

# %%
sns.histplot(data["number of week nights"],bins=range(0,6))
# Out:
# <Axes: xlabel='number of week nights', ylabel='Count'>

# %%
sns.histplot(data["car parking space"],bins=range(0,6))
# Out:
# <Axes: xlabel='car parking space', ylabel='Count'>

# %%
sns.histplot(data["lead time"],bins=range(0,6))
# Out:
# <Axes: xlabel='lead time', ylabel='Count'>

# %%
sns.histplot(data["repeated"],bins=range(0,6))
# Out:
# <Axes: xlabel='repeated', ylabel='Count'>

# %%
sns.histplot(data["booking status"],bins=range(0,6))
# Out:
# <Axes: xlabel='booking status', ylabel='Count'>

# %%
sns.histplot(data["meal"],bins=range(0,6))
# Out:
# <Axes: xlabel='meal', ylabel='Count'>

# %%
sns.histplot(data["room"],bins=range(0,6))
# Out:
# <Axes: xlabel='room', ylabel='Count'>

# %%
sns.countplot(
    x = "repeated",
    hue = "booking status",
    data = data
)
# Out:
# <Axes: xlabel='repeated', ylabel='count'>

# %%
data.corr()
# Out:
#                           number of adults  number of children  \
# number of adults                  1.000000           -0.020027
# number of children               -0.020027            1.000000
# number of weekend nights          0.103316            0.029536
# number of week nights             0.105416            0.024680
# car parking space                 0.011467            0.034198
# lead time                         0.097014           -0.047058
# repeated                         -0.192175           -0.036371
# P-C                              -0.047395           -0.016398
# P-not-C                          -0.119106           -0.021201
# average price                     0.296832            0.337491
# special requests                  0.189317            0.124363
# booking status                    0.086774            0.033007
# meal                              0.025359           -0.086872
# room                              0.270501            0.363802
# booking type                      0.314021            0.130536
#
#                           number of weekend nights  number of week nights  \
# number of adults                          0.103316               0.105416
# number of children                        0.029536               0.024680
# number of weekend nights                  1.000000               0.179548
# number of week nights                     0.179548               1.000000
# car parking space                        -0.031102              -0.048814
# lead time                                 0.046510               0.149600
# repeated                                 -0.067096              -0.099782
# P-C                                      -0.020687              -0.030089
# P-not-C                                  -0.026307              -0.049354
# average price                            -0.004565               0.022751
# special requests                          0.060432               0.046136
# booking status                            0.061489               0.092824
# meal                                     -0.027293              -0.083478
# room                                      0.057334               0.094142
# booking type                              0.129048               0.112940
#
#                           car parking space  lead time  repeated       P-C  \
# number of adults                   0.011467   0.097014 -0.192175 -0.047395
# number of children                 0.034198  -0.047058 -0.036371 -0.016398
# number of weekend nights          -0.031102   0.046510 -0.067096 -0.020687
# number of week nights             -0.048814   0.149600 -0.099782 -0.030089
# car parking space                  1.000000  -0.066444  0.110916  0.027109
# lead time                         -0.066444   1.000000 -0.135966 -0.045718
# repeated                           0.110916  -0.135966  1.000000  0.390811
# P-C                                0.027109  -0.045718  0.390811  1.000000
# P-not-C                            0.063814  -0.078126  0.539157  0.468148
# average price                      0.061310  -0.062578 -0.174881 -0.063334
# special requests                   0.087889  -0.101604 -0.011834 -0.003323
# booking status                    -0.086179   0.438491 -0.107277 -0.033725
# meal                              -0.012997  -0.060316 -0.062991 -0.011623
# room                               0.038778  -0.107830 -0.025819 -0.007934
# booking type                      -0.003734  -0.007080 -0.337748 -0.074228
#
#                            P-not-C  average price  special requests  \
# number of adults         -0.119106       0.296832          0.189317
# number of children       -0.021201       0.337491          0.124363
# number of weekend nights -0.026307      -0.004565          0.060432
# number of week nights    -0.049354       0.022751          0.046136
# car parking space         0.063814       0.061310          0.087889
# lead time                -0.078126      -0.062578         -0.101604
# repeated                  0.539157      -0.174881         -0.011834
# P-C                       0.468148      -0.063334         -0.003323
# P-not-C                   1.000000      -0.113673          0.027363
# average price            -0.113673       1.000000          0.184468
# special requests          0.027363       0.184468          1.000000
# booking status           -0.060174       0.142433         -0.253092
# meal                     -0.038180      -0.069268          0.022023
# room                     -0.008136       0.469908          0.145159
# booking type             -0.207140       0.375597          0.308467
#
#                           booking status      meal      room  booking type
# number of adults                0.086774  0.025359  0.270501      0.314021
# number of children              0.033007 -0.086872  0.363802      0.130536
# number of weekend nights        0.061489 -0.027293  0.057334      0.129048
# number of week nights           0.092824 -0.083478  0.094142      0.112940
# car parking space              -0.086179 -0.012997  0.038778     -0.003734
# lead time                       0.438491 -0.060316 -0.107830     -0.007080
# repeated                       -0.107277 -0.062991 -0.025819     -0.337748
# P-C                            -0.033725 -0.011623 -0.007934     -0.074228
# P-not-C                        -0.060174 -0.038180 -0.008136     -0.207140
# average price                   0.142433 -0.069268  0.469908      0.375597
# special requests               -0.253092  0.022023  0.145159      0.308467
# booking status                  1.000000  0.026772  0.022877      0.136005
# meal                            0.026772  1.000000 -0.209199      0.203363
# room                            0.022877 -0.209199  1.000000      0.156631
# booking type                    0.136005  0.203363  0.156631      1.000000

# %%
sns.heatmap(
    data = data.corr(),
    annot = True,
    cmap = 'coolwarm'
)
# Out:
# <Axes: >

# %%
def remove_outliers(data,col):
  Q1 = data[col].quantile(0.25)
  Q3 = data[col].quantile(0.75)

  IQR = Q3-Q1

  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3+1.5*IQR

  filtered_data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
  return filtered_data

# %%
data=remove_outliers(data,'number of adults')
data=remove_outliers(data,'number of children')
data=remove_outliers(data,'number of weekend nights')
data=remove_outliers(data,'number of week nights')
data=remove_outliers(data,'lead time')
data=remove_outliers(data,'average price')

# %%
data
# Out:
#        number of adults  number of children  number of weekend nights  \
# 9                     2                   0                         0
# 12                    2                   0                         2
# 14                    2                   0                         0
# 15                    2                   0                         0
# 17                    2                   0                         1
# ...                 ...                 ...                       ...
# 36278                 2                   0                         0
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36284                 2                   0                         0
#
#        number of week nights  car parking space  lead time  repeated  P-C  \
# 9                          5                  0         44         0    0
# 12                         1                  0         30         0    0
# 14                         2                  0         47         0    0
# 15                         2                  0        256         0    0
# 17                         3                  0          1         0    0
# ...                      ...                ...        ...       ...  ...
# 36278                      2                  0        211         0    0
# 36279                      1                  0         48         0    0
# 36281                      3                  0         34         0    0
# 36282                      3                  0         83         0    0
# 36284                      5                  0         44         0    0
#
#        P-not-C  average price  special requests  booking status  meal  room  \
# 9            0         133.44                 3               0     0     3
# 12           0          88.00                 0               1     3     0
# 14           0          94.50                 2               0     0     0
# 15           0         115.00                 1               1     1     0
# 17           0          96.00                 1               0     3     0
# ...        ...            ...               ...             ...   ...   ...
# 36278        0         100.00                 0               1     0     0
# 36279        0          94.50                 0               1     3     0
# 36281        0         107.55                 1               0     0     0
# 36282        0         105.61                 1               0     0     3
# 36284        0         133.44                 3               0     0     3
#
#        booking type
# 9                 4
# 12                4
# 14                4
# 15                4
# 17                4
# ...             ...
# 36278             4
# 36279             4
# 36281             4
# 36282             4
# 36284             4
#
# [22295 rows x 15 columns]

# %%
X = data.drop(columns = "booking status")
X
# Out:
#        number of adults  number of children  number of weekend nights  \
# 9                     2                   0                         0
# 12                    2                   0                         2
# 14                    2                   0                         0
# 15                    2                   0                         0
# 17                    2                   0                         1
# ...                 ...                 ...                       ...
# 36278                 2                   0                         0
# 36279                 2                   0                         1
# 36281                 2                   0                         1
# 36282                 2                   0                         1
# 36284                 2                   0                         0
#
#        number of week nights  car parking space  lead time  repeated  P-C  \
# 9                          5                  0         44         0    0
# 12                         1                  0         30         0    0
# 14                         2                  0         47         0    0
# 15                         2                  0        256         0    0
# 17                         3                  0          1         0    0
# ...                      ...                ...        ...       ...  ...
# 36278                      2                  0        211         0    0
# 36279                      1                  0         48         0    0
# 36281                      3                  0         34         0    0
# 36282                      3                  0         83         0    0
# 36284                      5                  0         44         0    0
#
#        P-not-C  average price  special requests  meal  room  booking type
# 9            0         133.44                 3     0     3             4
# 12           0          88.00                 0     3     0             4
# 14           0          94.50                 2     0     0             4
# 15           0         115.00                 1     1     0             4
# 17           0          96.00                 1     3     0             4
# ...        ...            ...               ...   ...   ...           ...
# 36278        0         100.00                 0     0     0             4
# 36279        0          94.50                 0     3     0             4
# 36281        0         107.55                 1     0     0             4
# 36282        0         105.61                 1     0     3             4
# 36284        0         133.44                 3     0     3             4
#
# [22295 rows x 14 columns]

# %%
y = data['booking status']
y
# Out:
# 9        0
# 12       1
# 14       0
# 15       1
# 17       0
#         ..
# 36278    1
# 36279    1
# 36281    0
# 36282    0
# 36284    0
# Name: booking status, Length: 22295, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
X_train
# Out:
#        number of adults  number of children  number of weekend nights  \
# 32033                 2                   0                         1
# 18176                 2                   0                         0
# 19197                 2                   0                         1
# 12718                 2                   0                         0
# 32165                 2                   0                         1
# ...                 ...                 ...                       ...
# 19364                 2                   0                         1
# 35182                 2                   0                         0
# 8628                  2                   0                         1
# 1349                  2                   0                         1
# 25697                 2                   0                         1
#
#        number of week nights  car parking space  lead time  repeated  P-C  \
# 32033                      5                  0         82         0    0
# 18176                      2                  0         23         0    0
# 19197                      1                  0        174         0    0
# 12718                      2                  0         44         0    0
# 32165                      3                  0         65         0    0
# ...                      ...                ...        ...       ...  ...
# 19364                      0                  0          5         0    0
# 35182                      3                  0          5         0    0
# 8628                       2                  0         58         0    0
# 1349                       1                  0         75         0    0
# 25697                      0                  0        286         0    0
#
#        P-not-C  average price  special requests  meal  room  booking type
# 32033        0          72.25                 1     3     0             4
# 18176        0         130.00                 1     0     0             4
# 19197        0          70.00                 0     0     0             3
# 12718        0          93.60                 1     3     0             4
# 32165        0          80.75                 0     0     0             3
# ...        ...            ...               ...   ...   ...           ...
# 19364        0          75.00                 1     3     0             4
# 35182        0         125.00                 0     1     0             3
# 8628         0         123.30                 2     0     3             4
# 1349         0          79.20                 1     3     0             4
# 25697        0          90.00                 0     0     0             3
#
# [15606 rows x 14 columns]

# %%
treemodel = DecisionTreeClassifier(max_depth=5)

# %%
treemodel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
plt.rcParams['figure.figsize'] = (70, 50)
tree.plot_tree(treemodel, 
               filled=True, 
               fontsize=50) 

plt.savefig('large_decision_tree.png', dpi=100)
plt.show()

# %%
y_pred=treemodel.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(6689,))

# %%
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.8349529077590073

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      4794
#            1       0.68      0.80      0.73      1895
#
#     accuracy                           0.83      6689
#    macro avg       0.80      0.83      0.81      6689
# weighted avg       0.85      0.83      0.84      6689

# %%
parameter = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [1,2,3,4,5],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV
treemodel=DecisionTreeClassifier()
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,scoring='accuracy')
cv.fit(X_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 150 fits failed out of a total of 450.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 150 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.72376388 0.68236611 0.66480842 0.67563828
#         nan        nan 0.69236369 0.6808271  0.70024327 0.68114933
#         nan        nan 0.70819131 0.68358443 0.7069733  0.68338714
#         nan        nan 0.76047572 0.69492656 0.75534907 0.70537185
#         nan        nan 0.73363015 0.69511694 0.76739456 0.70857254
#         nan        nan 0.68525058 0.68960816 0.702355   0.68172607
#         nan        nan 0.702355   0.67410031 0.73965021 0.68909551
#         nan        nan 0.73138467 0.70081983 0.7147924  0.71331629
#         nan        nan 0.75656772 0.70524145 0.73926477 0.71383113
#         nan        nan 0.7695736  0.70229207 0.77765138 0.69178625
#         nan        nan 0.68749345 0.67627916 0.68191284 0.66480842
#         nan        nan 0.709535   0.6803113  0.68352043 0.69659247
#         nan        nan 0.72235416 0.69819517 0.690569   0.6894121
#         nan        nan 0.73131901 0.73862765 0.73587538 0.71485065
#         nan        nan 0.76111506 0.69607534 0.73048636 0.69248625]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
plt.rcParams['figure.figsize'] = (10, 6)
display=ConfusionMatrixDisplay(cm)display.plot()
plot.show()
# Out:
#   Cell In[49], line 2
#     display=ConfusionMatrixDisplay(cm)display.plot()
#                                       ^
# SyntaxError: invalid syntax
