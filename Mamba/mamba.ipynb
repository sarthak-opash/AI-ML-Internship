# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# 130M parameter model
model_id = "state-spaces/mamba-130m-hf"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id).to("cpu")

prompt = "The future of AI is"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids

output = model.generate(
    input_ids, 
    max_length=20, 
    num_beams=1, 
    do_sample=True,
    temperature=0.7
)

# 4. Decode and print
print("/n/n/n/n")
print(f"Prompt: {prompt}")
print(f"Generated text: {tokenizer.decode(output[0], skip_special_tokens=True)}")
# Out:
# /n/n/n/n
# Prompt: The future of AI is
# Generated text: The future of AI is looking promising. As we’ve seen, it can help us solve problems
