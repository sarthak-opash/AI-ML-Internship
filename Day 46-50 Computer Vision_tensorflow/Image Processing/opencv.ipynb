# %%
! pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages (from opencv-python) (2.4.0)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages)

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %%
img = cv2.imread('luffy.jfif')
img
# Out:
# array([[[242, 255, 253],
#         [242, 255, 253],
#         [242, 255, 253],
#         ...,
#         [232, 254, 252],
#         [232, 254, 252],
#         [232, 254, 252]],
#
#        [[242, 255, 253],
#         [242, 255, 253],
#         [242, 255, 253],
#         ...,
#         [232, 254, 252],
#         [232, 254, 252],
#         [232, 254, 252]],
#
#        [[242, 255, 253],
#         [242, 255, 253],
#         [242, 255, 253],
#         ...,
#         [232, 254, 252],
#         [232, 254, 252],
#         [232, 254, 252]],
#
#        ...,
#
#        [[  9,   7,  27],
#         [  9,   7,  27],
#         [ 10,   8,  28],
#         ...,
#         [155, 154, 150],
#         [155, 154, 150],
#         [155, 154, 150]],
#
#        [[  9,   7,  27],
#         [  9,   7,  27],
#         [ 10,   8,  28],
#         ...,
#         [155, 154, 150],
#         [155, 154, 150],
#         [155, 154, 150]],
#
#        [[  9,   7,  27],
#         [  9,   7,  27],
#         [ 10,   8,  28],
#         ...,
#         [155, 154, 150],
#         [155, 154, 150],
#         [155, 154, 150]]], shape=(168, 300, 3), dtype=uint8)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_HSV = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 4, 1)
plt.imshow(img_rgb)
plt.title("Original Image (RGB)")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(img_gray)
plt.title("Grayscale Image")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(img_HSV)
plt.title("HSV Image")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(img_LAB)
plt.title("LAB Image")
plt.axis("off")



plt.tight_layout()
plt.show()

# %%
blue  = img[:, :, 0]
green = img[:, :, 1]
red   = img[:, :, 2]

img_blue  = blue
img_green = green
img_red   = red

# stack the single‑channel images side by side
new_img = np.hstack((img_blue, img_green, img_red))

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
plt.imshow(img_blue, cmap='gray')
plt.title("Blue channel")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(img_green, cmap='gray')
plt.title("Green channel")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(img_red, cmap='gray')
plt.title("Red channel")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
plt.imshow(img_blue)
plt.title("Blue channel")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(img_green)
plt.title("Green channel")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(img_red)
plt.title("Red channel")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
image = cv2.GaussianBlur(img, (5, 5), 0)
plt.imshow(image)

# %% [markdown]
# Morphological operation

# %%
image = cv2.imread('luffy.jfif', 0)  

kernel = np.ones((5,5), np.uint8)

erosion = cv2.erode(image, kernel, iterations=1)
dilation = cv2.dilate(image, kernel, iterations=1)
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

titles = ['Original Image', 'Erosion', 'Dilation', 'Opening', 'Closing']
images = [image, erosion, dilation, opening, closing]

for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])

plt.show()

# %%
canny = cv2.Canny(image, 100, 200)
plt.imshow(canny)

# %%
plt.imshow(canny, cmap='gray')

# %%
low_pass = cv2.Salt
