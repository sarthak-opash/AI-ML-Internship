# %%
import pandas as pd

# %%
data = {
    'Full_Address' : [ '129 Galleria Shopping, Surat, 12345']
}
df = pd.DataFrame(data)
print(df)
# Out:
#                           Full_Address
# 0  129 Galleria Shopping, Surat, 12345

# %%
df[['Street', 'City', 'Zipcode']] = df['Full_Address'].str.extract(
    r'([0-9]+\s[\w\s]+),\s([\w\s]+),\s(\d+)')

df.head()
# Out:
#                           Full_Address                 Street   City Zipcode
# 0  129 Galleria Shopping, Surat, 12345  129 Galleria Shopping  Surat   12345
