# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('bigmart.csv')
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
data.columns.tolist()
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
data['Item_Visibility'].hist(bins=50)
# Out:
# <Axes: >

# %%
item_visibility_log = np.log(data['Item_Visibility']+0.1)
item_visibility_log.hist(bins=50)
# Out:
# <Axes: >

# %%
visibility = data['Item_Visibility']*100
visibility.hist(bins=50)
# Out:
# <Axes: >

# %%
log_visibility = np.log(visibility+1)
log_visibility.hist(bins=50)
# Out:
# <Axes: >

# %%
temp = data['Item_Identifier'].value_counts()

# %%
data['item_id'] = data['Item_Identifier'].apply(lambda x: temp[x])
data[['item_id', 'Item_Identifier']].head()
# Out:
#    item_id Item_Identifier
# 0        8           FDA15
# 1        6           DRC01
# 2        7           FDN15
# 3        6           FDX07
# 4        6           NCD19

# %%
for i in range(0, len(data)):
    if data['item_id'][i] < 4:
        data['Item_Identifier'][i] = 'Other'
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# ...
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14340\3827811402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier'][i] = 'Other'

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales  item_id
# 8518  Supermarket Type1          2778.3834        8
# 8519  Supermarket Type1           549.2850        6
# 8520  Supermarket Type1          1193.1136        6
# 8521  Supermarket Type2          1845.5976        6
# 8522  Supermarket Type1           765.6700        5
