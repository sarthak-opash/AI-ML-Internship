# %% [markdown]
# Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x,y = iris.data,iris.target
gain = mutual_info_classif(x,y)
print(gain)
# Out:
# [0.53887713 0.2593946  0.987813   0.98695628]
