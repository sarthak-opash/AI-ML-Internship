# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
data = pd.read_csv("NIFTY 50.csv",index_col="Date")
print(data.head())
# Out:
#                Open     High      Low   Close      Volume      Turnover  \
# Date
# 2000-01-03  1482.15  1592.90  1482.15  1592.2  25358322.0  8.841500e+09
# 2000-01-04  1594.40  1641.95  1594.40  1638.7  38787872.0  1.973690e+10
# 2000-01-05  1634.55  1635.50  1555.05  1595.8  62153431.0  3.084790e+10
# 2000-01-06  1595.80  1639.00  1595.80  1617.6  51272875.0  2.531180e+10
# 2000-01-07  1616.60  1628.25  1597.20  1613.3  54315945.0  1.914630e+10
#
#               P/E   P/B  Div Yield
# Date
# 2000-01-03  25.91  4.63       0.95
# 2000-01-04  26.67  4.76       0.92
# 2000-01-05  25.97  4.64       0.95
# 2000-01-06  26.32  4.70       0.94
# 2000-01-07  26.25  4.69       0.94

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5061 entries, 2000-01-03 to 2020-05-08
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5061 non-null   float64
#  1   High       5061 non-null   float64
#  2   Low        5061 non-null   float64
#  3   Close      5061 non-null   float64
#  4   Volume     5060 non-null   float64
#  5   Turnover   5060 non-null   float64
#  6   P/E        5061 non-null   float64
#  7   P/B        5061 non-null   float64
#  8   Div Yield  5061 non-null   float64
# dtypes: float64(9)
# memory usage: 395.4+ KB
# None

# %%
print(data.describe())
# Out:
#                Open          High           Low         Close        Volume  \
# count   5061.000000   5061.000000   5061.000000   5061.000000  5.060000e+03
# mean    5216.237977   5251.466667   5174.455009   5213.433768  1.664416e+08
# std     3274.529979   3283.745772   3257.303609   3270.073955  1.419567e+08
# min      853.000000    877.000000    849.950000    854.200000  1.394931e+06
# 25%     1983.200000   1999.700000   1964.650000   1982.750000  7.772303e+07
# 50%     5096.700000   5135.550000   5038.850000   5090.850000  1.370860e+08
# 75%     7895.400000   7929.100000   7837.700000   7887.800000  1.983021e+08
# max    12430.500000  12430.500000  12321.400000  12362.300000  1.811564e+09
#
#            Turnover          P/E          P/B    Div Yield
# count  5.060000e+03  5061.000000  5061.000000  5061.000000
# mean   6.826187e+10    20.037014     3.547459     1.428164
# std    5.482144e+10     4.194021     0.799204     0.402380
# ...

# %%
print(data.shape)
# Out:
# (5061, 9)

# %%
print(data.isnull().sum())
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Volume       1
# Turnover     1
# P/E          0
# P/B          0
# Div Yield    0
# dtype: int64

# %%
print(data.nunique)
# Out:
# <bound method DataFrame.nunique of                Open     High      Low    Close       Volume      Turnover  \
# Date
# 2000-01-03  1482.15  1592.90  1482.15  1592.20   25358322.0  8.841500e+09
# 2000-01-04  1594.40  1641.95  1594.40  1638.70   38787872.0  1.973690e+10
# 2000-01-05  1634.55  1635.50  1555.05  1595.80   62153431.0  3.084790e+10
# 2000-01-06  1595.80  1639.00  1595.80  1617.60   51272875.0  2.531180e+10
# 2000-01-07  1616.60  1628.25  1597.20  1613.30   54315945.0  1.914630e+10
# ...             ...      ...      ...      ...          ...           ...
# 2020-05-04  9533.50  9533.50  9266.95  9293.50          NaN           NaN
# 2020-05-05  9429.40  9450.90  9190.75  9205.60  725196178.0  2.970020e+11
# 2020-05-06  9226.80  9346.90  9116.50  9270.90  722185448.0  3.079810e+11
# 2020-05-07  9234.05  9277.85  9175.90  9199.05  708740416.0  5.970553e+11
# 2020-05-08  9376.95  9382.65  9238.20  9251.50  609053504.0  3.074345e+11
#
#               P/E   P/B  Div Yield
# ...

# %%
data.index = pd.to_datetime(data.index)

plt.figure(figsize=(15, 10))
plt.plot(
    data.index,
    data['Close'],
    alpha=0.8,
    color='blue',
    label='Closing Price'
)
plt.plot(
    data.index,
    data['Open'],
    alpha=0.8,
    color='red',
    label='Opening Price'
)
plt.legend()
plt.show()

# %%
high_sort = data.sort_values(by='High', ascending=False)
#print(data.head(10))

# %%
plt.figure(figsize=(15, 10))
plt.plot (
    sorted['High'],
    sorted['Date'],
    color='orange',
    alpha=0.8,
    label='Top 50 High Prices',
    linestyle='--'
)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(
    data.index,
    data['P/E'],
    color="black",
    alpha=0.8,
    label='P/E'
)

plt.plot(
    data.index,
    data['P/B'],
    color="blue",
    alpha=0.8,
    label='P/B'
)
plt.legend()
plt.show()

# %%
sns.set_style('darkgrid')

numeric_columns = data.select_dtypes(include=["int64", "float64"]).columns
plt.figure( figsize=(14, len(numeric_columns)*3))

for idx, column in enumerate(numeric_columns):
    plt.subplot(len(numeric_columns), 1, idx+1)
    sns.histplot(data[column], kde=True, color='purple', bins=30)
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# %%
low_sort = data.sort_values(by='Low', ascending=True).head(50)
plt.figure(figsize=( len(low_sort)*3,50))
sns.boxplot(
    x=low_sort['High'],
    y=low_sort['Low'],
    data=low_sort
)
# Out:
# <Axes: xlabel='High', ylabel='Low'>

# %%
data.groupby(data.index.day_name())['Turnover'].mean()
# Out:
# Date
# Friday       7.165344e+10
# Monday       6.167087e+10
# Saturday     2.249827e+10
# Sunday       1.411408e+10
# Thursday     7.344625e+10
# Tuesday      6.677833e+10
# Wednesday    6.888209e+10
# Name: Turnover, dtype: float64

# %%
row = data.loc["2020-01-07"]
print(row)
# Out:
# Open         1.207910e+04
# High         1.215215e+04
# Low          1.200535e+04
# Close        1.205295e+04
# Volume       4.478186e+08
# Turnover     1.779768e+11
# P/E          2.803000e+01
# P/B          3.720000e+00
# Div Yield    1.250000e+00
# Name: 2020-01-07 00:00:00, dtype: float64
