# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axes = np.array([2,5])
y_axes = np.array([4,8])
plt.plot(x_axes, y_axes, marker='o')
plt.title("Simple Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid()
plt.show()

# %%
y_axis = ([1,8,3,5,77,88,45,212,2,3,0])
plt.plot(y_axis, marker='o')
plt.grid()
plt.show()

# %%
x_axes1 = np.array([2,5])
y_axes1 = np.array([4,8])
y_axis1 = ([1,8,3,5,77,88,45,212,2,3,0])

plt.subplot(1,2,1)
plt.plot(x_axes1, y_axes1, marker='o')

plt.subplot(1,2,2)
plt.plot(y_axis1, marker='o')

# %%
plt.scatter(range(len(y_axis)), y_axis, color='red', marker='x')

# %%
plt.bar(range(len(y_axis)), y_axis, color='green')
plt.show()

# %%
plt.barh(range(len(y_axis)), y_axis, color='green')
plt.show()

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x,bins=20)
# Out:
# (array([ 3.,  1.,  4.,  5., 10., 17., 16., 21., 40., 29., 26., 17., 21.,
#         13., 10.,  2.,  8.,  4.,  1.,  2.]),
#  array([145.04562453, 147.76425452, 150.4828845 , 153.20151449,
#         155.92014448, 158.63877447, 161.35740445, 164.07603444,
#         166.79466443, 169.51329442, 172.2319244 , 174.95055439,
#         177.66918438, 180.38781437, 183.10644436, 185.82507434,
#         188.54370433, 191.26233432, 193.98096431, 196.69959429,
#         199.41822428]),
#  <BarContainer object of 20 artists>)
