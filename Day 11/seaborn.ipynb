# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_style("whitegrid")
rs = np.random.RandomState(10)
data = rs.randn(100)

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data,kde=True,color='green')
# Out:
# <Axes: ylabel='Count'>

# %%
sns.lineplot(data)
# Out:
# <Axes: >

# %%
sns.displot(data)

# %%
colors = (['r','g','b'])

sns.distplot(data, 
             kde=True, 
             hist=True, 
             bins=10,
             rug=True,
             hist_kws={"alpha": 0.3, "color": colors[0]},
             kde_kws={"color": colors[1], "lw": 2},
             rug_kws={"color": colors[2]}
             )
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18816\2563742197.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,
# <Axes: ylabel='Density'>

# %%
import pandas as pd

sns.set_style("dark")
dataset = pd.read_csv("currency.csv")

plt.figure(figsize=(50,16))

sns.lineplot(
    x="Code",
      y="Symbol", 
      hue="Name",
      data=dataset)
      

plt.show()
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2547 (\N{BENGALI RUPEE SIGN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 3647 (\N{THAI CURRENCY SYMBOL BAHT}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Admin\AppData\Roaming\Python\Python314\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 6107 (\N{KHMER CURRENCY SYMBOL RIEL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.reshape(10,10), cbar=False)
plt.show()
