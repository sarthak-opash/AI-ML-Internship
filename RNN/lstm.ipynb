# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
data = pd.read_csv('monthly_milk_production.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
production = data['Production'].astype(float).values.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(production)

# %%
data
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727
# ...                ...
# 1975-08-01         858
# 1975-09-01         817
# 1975-10-01         827
# 1975-11-01         797
# 1975-12-01         843
#
# [168 rows x 1 columns]

# %%
window_size = 12
X = []
y = []
target_dates = data.index[window_size:]

for i in range(window_size, len(scaled_data)):
    X.append(scaled_data[i - window_size:i, 0])
    y.append(scaled_data[i, 0])

X = np.array(X)
y = np.array(y)

X_train, X_test, y_train, y_test, dates_train, dates_test = train_test_split(
    X, y, target_dates, test_size=0.2, shuffle=False
)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units=128, return_sequences=True,
          input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=128))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# d:\AIML Internship\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.1)

predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions).flatten()
y_test = scaler.inverse_transform(y_test.reshape(-1,1)).flatten()

rmse = np.sqrt(np.mean((y_test - predictions)**2))
print(f'RMSE: {rmse:.2f}')
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.1259 - val_loss: 0.0272
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0395 - val_loss: 0.0356
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0283 - val_loss: 0.0587
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0340 - val_loss: 0.0497
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0277 - val_loss: 0.0269
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0266 - val_loss: 0.0281
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0290 - val_loss: 0.0298
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0251 - val_loss: 0.0388
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0266 - val_loss: 0.0293
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0240 - val_loss: 0.0257
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0245 - val_loss: 0.0271
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0234 - val_loss: 0.0301
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0249 - val_loss: 0.0286
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0243 - val_loss: 0.0240
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0249 - val_loss: 0.0268
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0237 - val_loss: 0.0252
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0237 - val_loss: 0.0232
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0222 - val_loss: 0.0231
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0204 - val_loss: 0.0220
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0200 - val_loss: 0.0215
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0197 - val_loss: 0.0210
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0174 - val_loss: 0.0195
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0167 - val_loss: 0.0197
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0177 - val_loss: 0.0206
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0148 - val_loss: 0.0168
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0131 - val_loss: 0.0129
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0121 - val_loss: 0.0113
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0123 - val_loss: 0.0111
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0123 - val_loss: 0.0098
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0138 - val_loss: 0.0209
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0150 - val_loss: 0.0112
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0145 - val_loss: 0.0211
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0118 - val_loss: 0.0109
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0108 - val_loss: 0.0195
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0126 - val_loss: 0.0077
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0086 - val_loss: 0.0076
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067 - val_loss: 0.0069
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104 - val_loss: 0.0312
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0086 - val_loss: 0.0061
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - val_loss: 0.0068
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0071 - val_loss: 0.0047
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0083 - val_loss: 0.0054
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0071 - val_loss: 0.0158
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0081 - val_loss: 0.0228
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0074 - val_loss: 0.0042
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0054 - val_loss: 0.0138
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0062 - val_loss: 0.0042
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0064 - val_loss: 0.0034
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0042 - val_loss: 0.0027
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0050 - val_loss: 0.0062
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0045 - val_loss: 0.0031
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0041 - val_loss: 0.0073
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0040 - val_loss: 0.0075
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0047 - val_loss: 0.0089
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0051 - val_loss: 0.0100
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0051 - val_loss: 0.0104
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0036 - val_loss: 0.0117
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0080 - val_loss: 0.0160
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0039 - val_loss: 0.0034
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0044 - val_loss: 0.0094
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0032 - val_loss: 0.0074
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0039 - val_loss: 0.0084
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0036 - val_loss: 0.0075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# RMSE: 38.17

# %%
plt.figure(figsize=(12, 6))
plt.plot(dates_test, y_test, label='Actual Production')
plt.plot(dates_test, predictions, label='Predicted Production')
plt.title('Actual vs Predicted Milk Production')
plt.xlabel('Date')
plt.ylabel('Production (pounds per cow)')
plt.legend()
plt.show()
